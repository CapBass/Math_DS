# %% [markdown]
# __1.__ Найти собственные векторы и собственные значения для линейного оператора, заданного матрицей
#
# $$A=\begin{pmatrix}
# -1 & -6\\
# 2 & 6
# \end{pmatrix}.$$

# %% [markdown]
# __Решение__
#
# Составим характеристическое уравнение
#
# $$A=\begin{vmatrix}
# -1 - \lambda & -6\\
# 2 & 6 - \lambda
# \end{vmatrix} = ((-1 - \lambda) * (6 - \lambda) - 2 * (-6)) = 0$$
#
# $$((-1 - \lambda) * (6 - \lambda) - 2 * (-6)) = -6 - 6\lambda + \lambda + \lambda^2 + 12 = \lambda^2 - 5\lambda + 6 = 0$$
#
# $$D = 25 - 4 * 1 * 6 = 1$$
#
# $$\lambda_1 = \frac{5 + 1}{2} = 3, \lambda_2 = \frac{5 - 1}{2} = 2$$

# %% [markdown]
# Прдставим собственные значения оператора в систему уравнений
#
# $$\begin{cases}
# (-1 - \lambda)x_1 - 6x_2= 0, \\
# 2x_1 + (6 - \lambda)x_2 = 0
# \end{cases}$$
#
# Для $ \lambda = 2$
#
#
# $$\begin{cases}
# -3x_1 - 6x_2= 0, \\
# 2x_1 + 4x_2 = 0
# \end{cases} => x_1 = -2x_2 $$
#
# Изменяя переменные x_1 или x_2 мы можем получить бесконечное количество собственных векторов. Для простоты возьмем $x_2 = -1$ тогда $x_1 = 2 $. Проверим, что найден вектор удовлетовряет условию
#
# $$\begin{cases}
# -3*2 - 6 * -1 = 0, \\
# 2 * 2 - 4 * -1 = 0
# \end{cases}$$
#
# Для $ \lambda = 3$
#
#
# $$\begin{cases}
# -4x_1 - 6x_2= 0, \\
# 2x_1 + 3x_2 = 0
# \end{cases} => x_1 = -\frac{3}{2}x_2 $$
#
# Изменяя переменные x_1 или x_2 мы можем получить бесконечное количество собственных векторов. Для простоты возьмем $x_2 = -2$ тогда $x_1 = 3 $. Проверим, что найденный вектор удовлетовряет условию
#
# $$\begin{cases}
# -4*3 - 6 * -2 = 0, \\
# 2 * 3 - 3 * -2 = 0
# \end{cases}$$
#
# Ответ: осбтсвенные значения линейного оператора $A$ равны $2$ и $3$, собственные векторы: $u_1 = \begin{pmatrix}
# 2\\
# -1
# \end{pmatrix},   u_2= \begin{pmatrix}
# 3\\
# -2
# \end{pmatrix}.$

# %% [markdown]
# __2.__ Дан оператор поворота на 180 градусов, задаваемый матрицей
#
# $$A=\begin{pmatrix}
# -1 & 0\\
# 0 & -1
# \end{pmatrix}.$$
#
# Показать, что __любой__ вектор является для него собственным.

# %% [markdown]
# __Решение__
#
# Проверим, что любой вектор $x = (x_1, x_2)$ удовлетворяет условию
#
# $$A=\begin{pmatrix}
# -1 & 0\\
# 0 & -1
# \end{pmatrix}\begin{pmatrix}
# x_1\\
# x_2
# \end{pmatrix} = \lambda\begin{pmatrix}
# x_1\\
# x_2
# \end{pmatrix} $$
#  тогда
# $$\begin{cases}
# -1x_1 =\lambda x_1 \\
# -1x_2 = \lambda x_2
# \end{cases}
# \Rightarrow
# \begin{cases}
# \lambda=-1\\
# \lambda=-1
# \end{cases}.$$
#
# Отсюда следует, что любой вектор для данного линейного оператора будет являться собственным вектором, собственное значение которого будет равно -1

# %% [markdown]
# __3.__ Пусть линейный оператор задан матрицей
#
# $$A=\begin{pmatrix}
# 1 & 1\\
# -1 & 3
# \end{pmatrix}.$$
#
# Установить, является ли вектор $x=(1,1)$ собственным вектором этого линейного оператора.

# %% [markdown]
# __Решение__
#
# Предположим, что вектор $x$ является собственным вектором заданного линейного оператора, тогда должно существовать некоторое вещественное число $\lambda$, при котором
#
# $$\begin{pmatrix}
# 1 & 1\\
# -1 & 3
# \end{pmatrix}
# \begin{pmatrix}
# 1\\
# 1
# \end{pmatrix}=
# \lambda
# \begin{pmatrix}
# 1\\
# 1
# \end{pmatrix}.
# $$
#
# Из этого будет следовать, что
#
# $$\begin{cases}
# 1+1=\lambda \\
# -1+3 = \lambda
# \end{cases}
# \Rightarrow
# \begin{cases}
# \lambda=2\\
# \lambda=2
# \end{cases}.$$
#
# Подставим $\lambda$  в выражение.
#
# $$\begin{pmatrix}
# 1 & 1\\
# -1 & 3
# \end{pmatrix}
# \begin{pmatrix}
# 1\\
# 1
# \end{pmatrix}=
# 2
# \begin{pmatrix}
# 1\\
# 1
# \end{pmatrix} =
# \begin{pmatrix}
# 2\\
# 2
# \end{pmatrix}
# $$
#
# Отсюда следует, что вектор $x=(1,1)$ является собственным вектором и его собственное значение равно 2

# %% [markdown]
# __4.__ Пусть линейный оператор задан матрицей
#
# $$A=\begin{pmatrix}
# 0 & 3 & 0\\
# 3 & 0 & 0\\
# 0 & 0 & 3
# \end{pmatrix}.$$
#
# Установить, является ли вектор $x=(3, -3, -4)$ собственным вектором этого линейного оператора.

# %% [markdown]
# $$A=\begin{pmatrix}
# 0 & 3 & 0\\
# 3 & 0 & 0\\
# 0 & 0 & 3
# \end{pmatrix}\begin{pmatrix}
# 3\\
# -3\\
# -4
# \end{pmatrix} = \lambda
# \begin{pmatrix}
# 3\\
# -3\\
# -4
# \end{pmatrix}$$
#
#
# $$\begin{cases}
# -9=3\lambda \\
# 9 = -3\lambda\\
# -12 = -4\lambda
# \end{cases}
# \Rightarrow
# \begin{cases}
# \lambda= -3\\
# \lambda= -3\\
# \lambda = 3
# \end{cases}.$$

# %% [markdown]
# Такая система не имеет смысла, следовательно, вектор x=(3,−3, -4) не является собственным вектором линейного оператора, заданного матрицей A.
